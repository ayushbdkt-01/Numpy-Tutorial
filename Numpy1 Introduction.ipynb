# %%
# !pip install numpy

# %% [markdown]
# # New Section

# %%
import numpy as np

# %%
l=[1,2,3]

# %%
l

# %%
type(l)

# %%
arr=np.array(l)

# %%
arr

# %%
type(arr)

# %%
arr.ndim

# %%
arr.shape

# %%
arr.size

# %%
arr.dtype

# %%
z=np.zeros((3,3))

# %%
z

# %%
o=np.ones((2,6))

# %%
o
